# %% [markdown]
# <a href="https://colab.research.google.com/github/saivenkat-p/PW-SKILLS/blob/main/Aggregations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Question 1

# %% [markdown]
# **Question:** Count how many cities are there in each country.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")



query = """
SELECT CountryCode, COUNT(*) AS CityCount
FROM city
GROUP BY CountryCode;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['CountryCode', 'CityCount']
# ('ARG', 1)
# ('AUS', 1)
# ('BRA', 1)
# ('CAN', 2)
# ('CHN', 1)
# ('DEU', 1)
# ('EGY', 1)
# ('FRA', 1)
# ('GBR', 1)
# ('IND', 1)
# ('JPN', 1)
# ('MEX', 1)
# ('NGA', 1)
# ('USA', 3)

# %% [markdown]
# ### Question 2

# %% [markdown]
# **Question:** Display all continents having more than 30 countries.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")



query = """
SELECT Continent, COUNT(*) AS CountryCount
FROM country
GROUP BY Continent
HAVING COUNT(*) > 30;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Continent', 'CountryCount']

# %% [markdown]
# ### Question 3

# %% [markdown]
# **Question:** List regions whose total population exceeds 200 million.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")



query = """
SELECT Region, SUM(Population) AS TotalPopulation
FROM country
GROUP BY Region
HAVING SUM(Population) > 200000000;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Region', 'TotalPopulation']
# ('Eastern Asia', 1566000000)
# ('North America', 497000000)
# ('South America', 258000000)
# ('Southern Asia', 1380000000)
# ('Western Africa', 206000000)
# ('Western Europe', 215000000)

# %% [markdown]
# ### Question 4

# %% [markdown]
# **Question:** Find the top 5 continents by average GNP per country.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")


query = """
SELECT Continent, AVG(GNP) AS AverageGNP
FROM country
GROUP BY Continent
ORDER BY AverageGNP DESC
LIMIT 5;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Continent', 'AverageGNP']
# ('North America', 7966666.666666667)
# ('Asia', 7300000.0)
# ('Europe', 3133333.3333333335)
# ('Oceania', 1400000.0)
# ('South America', 925000.0)

# %% [markdown]
# ### Question 5

# %% [markdown]
# **Question:** Find the total number of official languages spoken in each continent.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")


query = """
SELECT c.Continent, COUNT(DISTINCT cl.Language) AS OfficialLanguages
FROM country c
JOIN countrylanguage cl
ON c.Code = cl.CountryCode
WHERE cl.IsOfficial = 'T'
GROUP BY c.Continent;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Continent', 'OfficialLanguages']
# ('Africa', 2)
# ('Asia', 3)
# ('Europe', 3)
# ('North America', 3)
# ('Oceania', 1)
# ('South America', 2)

# %% [markdown]
# ### Question 6

# %% [markdown]
# **Question:** Find the maximum and minimum GNP for each continent.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")


query = """
SELECT Continent,
       MAX(GNP) AS MaximumGNP,
       MIN(GNP) AS MinimumGNP
FROM country
GROUP BY Continent;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Continent', 'MaximumGNP', 'MinimumGNP']
# ('Africa', 450000.0, 300000.0)
# ('Asia', 14000000.0, 2900000.0)
# ('Europe', 3800000.0, 2700000.0)
# ('North America', 21000000.0, 1200000.0)
# ('Oceania', 1400000.0, 1400000.0)
# ('South America', 1400000.0, 450000.0)

# %% [markdown]
# ### Question 7

# %% [markdown]
# **Question:** Find the country with the highest average city population.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")


query = """
SELECT c.Name AS Country, AVG(ci.Population) AS AverageCityPopulation
FROM country c
JOIN city ci
ON c.Code = ci.CountryCode
GROUP BY c.Code, c.Name
ORDER BY AverageCityPopulation DESC
LIMIT 1;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Country', 'AverageCityPopulation']
# ('China', 26000000.0)

# %% [markdown]
# ### Question 8

# %% [markdown]
# **Question:** List continents where the average city population is greater than 200,000.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")


query = """
SELECT c.Continent, AVG(ci.Population) AS AverageCityPopulation
FROM country c
JOIN city ci
ON c.Code = ci.CountryCode
GROUP BY c.Continent
HAVING AVG(ci.Population) > 200000;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Continent', 'AverageCityPopulation']
# ('Africa', 12300000.0)
# ('Asia', 20000000.0)
# ('Europe', 4900000.0)
# ('North America', 4579166.666666667)
# ('Oceania', 5300000.0)
# ('South America', 7600000.0)

# %% [markdown]
# ### Question 9

# %% [markdown]
# **Question:** Find the total population and average life expectancy for each continent, ordered by average life expectancy descending.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")


query = """
SELECT Continent,
       SUM(Population) AS TotalPopulation,
       AVG(LifeExpectancy) AS AverageLifeExpectancy
FROM country
GROUP BY Continent
ORDER BY AverageLifeExpectancy DESC;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Continent', 'TotalPopulation', 'AverageLifeExpectancy']
# ('Oceania', 25000000, 83.0)
# ('Europe', 215000000, 81.5)
# ('North America', 497000000, 78.5)
# ('Asia', 2946000000, 76.66666666666667)
# ('South America', 258000000, 76.2)
# ('Africa', 308000000, 63.0)

# %% [markdown]
# ### Question 10

# %% [markdown]
# **Question:** Find the top 3 continents with the highest average life expectancy, but only include those where the total population is over 200 million.

# %% [markdown]
# **Answer:**

# %%
import sqlite3

conn = sqlite3.connect(':memory:')
cursor = conn.cursor()

# Create tables and insert data based on the World database schema
cursor.execute('''
CREATE TABLE country (
    Code TEXT PRIMARY KEY,
    Name TEXT,
    Continent TEXT,
    Region TEXT,
    SurfaceArea REAL,
    IndepYear INTEGER,
    Population INTEGER,
    LifeExpectancy REAL,
    GNP REAL,
    GNPOld REAL,
    LocalName TEXT,
    GovernmentForm TEXT,
    HeadOfState TEXT,
    Capital INTEGER,
    Code2 TEXT
);
''')

cursor.execute('''
CREATE TABLE city (
    ID INTEGER PRIMARY KEY,
    Name TEXT,
    CountryCode TEXT,
    District TEXT,
    Population INTEGER,
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

cursor.execute('''
CREATE TABLE countrylanguage (
    CountryCode TEXT,
    Language TEXT,
    IsOfficial TEXT,
    Percentage REAL,
    PRIMARY KEY (CountryCode, Language),
    FOREIGN KEY (CountryCode) REFERENCES country(Code)
);
''')

# Example data for 'world' database tables
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('USA', 'United States', 'North America', 331000000, 21000000, 78.5, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CAN', 'Canada', 'North America', 38000000, 1700000, 82.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('MEX', 'Mexico', 'North America', 128000000, 1200000, 75.0, 'North America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('BRA', 'Brazil', 'South America', 213000000, 1400000, 75.9, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('ARG', 'Argentina', 'South America', 45000000, 450000, 76.5, 'South America')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('GBR', 'United Kingdom', 'Europe', 67000000, 2700000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('FRA', 'France', 'Europe', 65000000, 2900000, 82.5, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('DEU', 'Germany', 'Europe', 83000000, 3800000, 81.0, 'Western Europe')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('JPN', 'Japan', 'Asia', 126000000, 5000000, 84.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('CHN', 'China', 'Asia', 1440000000, 14000000, 77.0, 'Eastern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('IND', 'India', 'Asia', 1380000000, 2900000, 69.0, 'Southern Asia')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('AUS', 'Australia', 'Oceania', 25000000, 1400000, 83.0, 'Australia and New Zealand')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('EGY', 'Egypt', 'Africa', 102000000, 300000, 71.0, 'Northern Africa')")
cursor.execute("INSERT INTO country (Code, Name, Continent, Population, GNP, LifeExpectancy, Region) VALUES ('NGA', 'Nigeria', 'Africa', 206000000, 450000, 55.0, 'Western Africa')")

cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (1, 'New York', 'USA', 8400000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (2, 'Los Angeles', 'USA', 4000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (3, 'Toronto', 'CAN', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (4, 'Mexico City', 'MEX', 9200000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (5, 'Sao Paulo', 'BRA', 12300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (6, 'Buenos Aires', 'ARG', 2900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (7, 'London', 'GBR', 8900000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (8, 'Paris', 'FRA', 2100000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (9, 'Berlin', 'DEU', 3700000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (10, 'Tokyo', 'JPN', 14000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (11, 'Shanghai', 'CHN', 26000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (12, 'Mumbai', 'IND', 20000000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (13, 'Sydney', 'AUS', 5300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (14, 'Cairo', 'EGY', 9800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (15, 'Lagos', 'NGA', 14800000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (16, 'Houston', 'USA', 2300000)")
cursor.execute("INSERT INTO city (ID, Name, CountryCode, Population) VALUES (17, 'Vancouver', 'CAN', 675000)")

cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'English', 'T', 82.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('USA', 'Spanish', 'F', 13.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'English', 'T', 58.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CAN', 'French', 'T', 22.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('MEX', 'Spanish', 'T', 92.1)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('BRA', 'Portuguese', 'T', 97.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('ARG', 'Spanish', 'T', 98.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('GBR', 'English', 'T', 97.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('FRA', 'French', 'T', 93.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('DEU', 'German', 'T', 91.5)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('JPN', 'Japanese', 'T', 99.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('CHN', 'Mandarin', 'T', 70.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'Hindi', 'T', 43.6)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('IND', 'English', 'F', 12.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('AUS', 'English', 'T', 76.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('EGY', 'Arabic', 'T', 98.8)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'English', 'T', 50.0)")
cursor.execute("INSERT INTO countrylanguage (CountryCode, Language, IsOfficial, Percentage) VALUES ('NGA', 'Hausa', 'F', 18.5)")


query = """
SELECT Continent,
       SUM(Population) AS TotalPopulation,
       AVG(LifeExpectancy) AS AverageLifeExpectancy
FROM country
GROUP BY Continent
HAVING SUM(Population) > 200000000
ORDER BY AverageLifeExpectancy DESC
LIMIT 3;
"""

# Execute the query
cursor.execute(query)

# Fetch all results
results = cursor.fetchall()

# Get column names
column_names = [description[0] for description in cursor.description]

# Print results with column names
print(column_names)
for row in results:
    print(row)

conn.close()
# Out:
# ['Continent', 'TotalPopulation', 'AverageLifeExpectancy']
# ('Europe', 215000000, 81.5)
# ('North America', 497000000, 78.5)
# ('Asia', 2946000000, 76.66666666666667)
