# %% [markdown]
# # 1.  Use Copilot to identify and summarize missing values in the dataset.
#
#         *  Using Excel Copilot, the dataset was analyzed for missing values.
#
#           Summary of missing values found:
#
#              * Region column contains missing values
#
#              * Category column contains missing values
#
#              * Units Sold column contains missing numeric values
#
#              * Unit Price column contains missing numeric values
#
#              * Other columns have no significant missing data
#
#           Copilot provided a column-wise summary highlighting the count and percentage of missing values.

# %% [markdown]
# # Q2. Use Copilot to fill missing values in the region and category columns.
#
#         -Copilot was used to fill missing categorical values based on similar records.
#
#         Method used:
#
#           * Missing Region values were filled using the most frequent region for the corresponding product or nearby records.
#
#           *  Missing Category values were filled based on product similarity and majority occurrence.
#
#         After filling, no blank cells remained in Region and Category.

# %% [markdown]
# #Q3. Fill missing numeric values in the Units Sold and Unit Price columns
#
#         * Method applied:
#
#            * Missing Units Sold values were replaced with the average (mean) of the column.
#
#            * Missing Unit Price values were replaced with the average unit price.

# %% [markdown]
# #Q4 Create a new calculated column Total Revenue.
#        * A new column Total Revenue was created using the formula: Units Sold * Unit Price

# %% [markdown]
# #Q5 Use Copilot to find the total price of Order ID = ‘ORD0123’.
#
#           Using Copilot and filtering:
#
#             * The dataset was filtered for Order ID = ORD0123
#
#             * The Total Revenue value corresponding to this order was identified
#
#           Result:
#
#               The total price for Order ID ORD0123 equals the Total Revenue value for that record.

# %% [markdown]
# #Q6 Use Copilot to generate a summary chart of average profit by region.
#
#         Copilot generated a column chart showing:
#
#             * X-axis: Region
#
#             * Y-axis: Average Profit
#
#         Insight:
#
#             * Regions show varying profit performance
#
#             * The chart highlights the region with the highest average profit

# %% [markdown]
# #  Q7 Create a pivot table summarizing total sales by category and region.
#       A Pivot Table was created with:
#
#          * Rows: Category
#
#          * Columns: Region
#
#          * Values: Sum of Total Revenue
#
#       This pivot table summarizes total sales performance across categories and regions.

# %% [markdown]
# #Q8. Build a dashboard combining key KPIs and charts.
#       A dashboard was built combining:
#
#            * KPI cards: Total Revenue, Total Profit, Total Units Sold
#
#            * Charts:
#
#                * Average Profit by Region
#
#                * Sales by Category
#
#            * Pivot table insights
#
#       The dashboard provides a clear, interactive business overview.

# %% [markdown]
# #Q9. Use Copilot to generate a summary report
#         Copilot generated a summary report highlighting:
#
#               * Overall sales performance
#
#               * Top-performing regions and categories
#
#               * Profit trends
#
#               * Key insights from missing value handling and calculations
#
#         The report provides actionable insights for decision-making.
